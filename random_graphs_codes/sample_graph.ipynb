# %%
# %run "real_network.ipynb"

# %%
# Let us take one graph as an example to test our functions (small test case)
adj = dict()
adj[1] = [2, 3, 4, 8]
adj[2] = [1, ]
adj[3] = [1, 4, 6]
adj[4] = [1, 3, 6]
adj[6] = [3, 4]
adj[7] = list()
adj[8] = [1, ]

# %%
# creating an object 
checker = check_properties()

# %%
checker.check(adj)
# Out:
# Number of vertices in the graph is n =  7
# Number of edges in the graph is n =  14
# Average distance between any two nodes is =  1.6666666666666667
# Clustering coefficient of graph G =  0.4166666666666667

# %%
import numpy as np

def sample_from_tanh(num_samples):
    # Generate random numbers uniformly distributed between 0 and 1
    random_uniform = np.random.rand(num_samples)
    print(random_uniform)
    # Use the inverse tanh function to transform random numbers into tanh values
    return
    tanh_values = np.tanh(np.arctanh(-1) + 2 * np.arctanh(random_uniform))
    return
    return tanh_values

# Example usage:
num_samples = 1000
samples = sample_from_tanh(num_samples)
# Out:
# [0.70706629 0.33679576 0.3667384  0.53830391 0.23693889 0.38857903
#  0.13566515 0.6688021  0.03465759 0.8695298  0.91274126 0.58915519
#  0.39035182 0.17732483 0.62209532 0.2134251  0.66815976 0.978991
#  0.31391117 0.53536888 0.88654062 0.72007284 0.81663427 0.67860662
#  0.52490218 0.60930194 0.52625487 0.58885323 0.37723252 0.7907761
#  0.57263812 0.29046418 0.40242084 0.25150973 0.25532524 0.5429321
#  0.47566386 0.97965357 0.30548726 0.02570991 0.78160902 0.52764825
#  0.99378141 0.35457327 0.51756068 0.08321509 0.32046199 0.00139637
#  0.01121802 0.54488252 0.88490253 0.18404813 0.29211117 0.11486174
#  0.83914832 0.006903   0.47734714 0.0217225  0.94964545 0.69353011
#  0.7572049  0.14692726 0.72821947 0.51157241 0.25878216 0.09056943
#  0.73501463 0.32195015 0.41846048 0.19523961 0.23602746 0.41529645
#  0.24912915 0.51516815 0.40408099 0.83948594 0.4250364  0.04689244
#  0.12909265 0.18016252 0.03472561 0.50543502 0.70895137 0.97393127
# ...

# %%
print(samples)
# Out:
# None
